# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"/Users/roshanthankar/Downloads/Latest Covid-19 India Status.csv")

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         8397     479        7789
# 1                             Andhra Pradesh      2087879   10119     2063255
# 2                          Arunachal Pradesh        56010     665       55063
# 3                                      Assam       635050   13139      615722
# 4                                      Bihar       762458   28660      721684
# 5                                 Chandigarh        71303    4808       65411
# 6                               Chhattisgarh      1038060   27425      997008
# 7   Dadra and Nagar Haveli and Daman and Diu        10856     144       10708
# 8                                      Delhi      1617716   87445     1505031
# 9                                        Goa       197096   14134      179423
# 10                                   Gujarat       885718   43726      831855
# ...

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population'],
#       dtype='object')

# %% [markdown]
# ##### relating the variables with scatterplots

# %%
sns.relplot(x="Total Cases", y="Population", hue="Deaths", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Total Cases",y="Deaths",kind="line",data=data)

# %%
sns.catplot(x="Total Cases",y="Death Ratio",data=data)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         8397     479        7789
# 1                             Andhra Pradesh      2087879   10119     2063255
# 2                          Arunachal Pradesh        56010     665       55063
# 3                                      Assam       635050   13139      615722
# 4                                      Bihar       762458   28660      721684
# 5                                 Chandigarh        71303    4808       65411
# 6                               Chhattisgarh      1038060   27425      997008
# 7   Dadra and Nagar Haveli and Daman and Diu        10856     144       10708
# 8                                      Delhi      1617716   87445     1505031
# 9                                        Goa       197096   14134      179423
# 10                                   Gujarat       885718   43726      831855
# ...

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population'],
#       dtype='object')

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar         8397     479        7789
# 1                             Andhra Pradesh      2087879   10119     2063255
# 2                          Arunachal Pradesh        56010     665       55063
# 3                                      Assam       635050   13139      615722
# 4                                      Bihar       762458   28660      721684
# 5                                 Chandigarh        71303    4808       65411
# 6                               Chhattisgarh      1038060   27425      997008
# 7   Dadra and Nagar Haveli and Daman and Diu        10856     144       10708
# 8                                      Delhi      1617716   87445     1505031
# 9                                        Goa       197096   14134      179423
# 10                                   Gujarat       885718   43726      831855
# ...

# %%
data.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar         8397     479        7789     129          5.70
# 1       Andhra Pradesh      2087879   10119     2063255   14505          0.48
# 2    Arunachal Pradesh        56010     665       55063     282          1.19
# 3                Assam       635050   13139      615722    6189          2.07
# 4                Bihar       762458   28660      721684   12114          3.76
#
#    Discharge Ratio  Death Ratio  Population
# 0            92.76         1.54      399001
# 1            98.82         0.69    91702478
# 2            98.31         0.50     1711947
# 3            96.96         0.97    35998752
# 4            94.65         1.59   128500364
